# %% [markdown]
# <a href="https://colab.research.google.com/github/missaixxka/HomeworkJava/blob/main/Stepik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание на 5 баллов**

# %% [markdown]
# # 3 раздел

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4 раздел

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6 раздел

# %% [markdown]
# ![image.png](data:image/png;base64,...)
