# %% [markdown]
# <a href="https://colab.research.google.com/github/missaixxka/HomeworkJava/blob/main/portswigger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание на 6 баллов**

# %% [markdown]
# # Server-side vulnerabilities

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Authentication vulnerabilities

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # API testing

# %% [markdown]
# ![image.png](data:image/png;base64,...)
