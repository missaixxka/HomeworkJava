# %% [markdown]
# <a href="https://colab.research.google.com/github/missaixxka/HomeworkJava/blob/main/java_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Теория ООП(3 балла)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
